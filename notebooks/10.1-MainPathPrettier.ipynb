# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cluster_label_dict = {
    "0": "Aquatic Ecotoxicology",
    "1": "5-ht autoreceptors; animal studies",
    "2": "P450 System; Metabolism; Pharmacokinetics",
    "3": "SSRIs during Pregnancy",
    "4": "Obsessive Compulsive Disorder Treatment",
    "5": "chromatography; ssri detection",
    "6": "Children and adolescents",
    "7": " hippocampal neurogenesis; animal studies",
    "8": "chronic unpredictable mild stress; animal studies; animal model of depression",
    "9": "pregnancy; animal studies; prenatal exposure",
    "10": "binding, receptor; animal studies;sert",
    "11": "affect response alteration; experimental psych",
    "12": "pharmacology; Enantiomers",
    "13": "ssri induced sexual dysfunction",
    "14": "pharmacotherapy of ptsd",
    "15": "serotonin syndrome",
    "16": "forced swimming test; animal studies",
    "17": "post stroke depression",
    "18": "escitalopram;efficacy; comparative effectiveness",
    "19": "prescription trends",
    "20": "cardiovascular effects",
    "21": "pharmacogenetics",
    "22": "star D, treatment combinations",
    "23": " anti-inflammatory effect",
    "24": "pain",
    "25": "dementia",
    "27": "suicide",
    "26": "efficacy",
    "28": "bleeding risk",
    "29": "weight management",
    "30": "fear; animal studies",
    "31": "pharmacological management of depressive disorders",
    "32": "paroxetine",
    "33": "panic disorder",
    "34": "Bipolar disorder pharmacotherapy",
    "35": "SSRIs for anxiety disorders",
    "36": "fluoxetine",
    "37": "Cost-effectiveness",
    "38": "worse movement after ssri",
    "39": "psychodermatology",
    "40": "fractures; fragility",
    "41": "QT interval prolongation",
    "42": "Covid",
    "43": "herbal extracts ",
    "44": "cancer and ssris",
    "45": "premature ejaculation",
    "46": "effect on sleep",
    "47": "memory and ssris",
    "48": "pmdd",
    "49": "diabetes",
    "50": "ibs (irritable bowel syndrome)",
    "51": "eating disorders",
    "52": "alcoholism",
    "53": "borderline personality disorder",
    "54": "parkinsons disease",
    "55": "epilepsy",
    "56": "social phobia",
    "57": "hot flashes; meopausal women",
    "58": "autism spectrum disorder",
    "59": "schizophrenia",
    "60": "cocaine ssri interaction; animal studies",
    "61": "drug release; pharmacokinetics; in vitro",
    "62": "synthesis; in vitro",
    "63": "sert, serotonin transporter",
    "64": "trends and updates",
    "65": "ion channels; in vitro; in vivo",
    "66": "mdma; animal studies; neurotoxic",
    "67": "genetic variations in cytochrome P450 enzymes",
    "68": "hyponatremia (low sodium in blood); ssri induced",
    "69": "late life depression",
    "70": "withdrawal",
    "71": "drug-drug interactions",
    "72": "body dysmorphic disorder; compulsions; sexuak",
    "73": "forensic toxicology,",
    "74": "neuroendocrine effects of citalopram",
    "75": "pulmonary hypertension; animal studies",
    "76": "compounds; in vivo; synthesis",
    "77": "gut bacteria; antifungal; in vivo; in vitro",
    "78": "agomelatine; (comparative) effectiveness and safety",
    "79": "astrocytes; mechanism of action",
    "80": "depression associated with hepatitis C ",
    "81": "animal studies; oxidative stress, mitochondrial function, and hematological parameters",
    "82": "safety; adverse  effects",
    "83": "sertraline for depression; clinical studies",
    "84": "ssris following tbi",
    "85": "modulation of hippocampal function and neurotransmission by serotonin, glutamate, and GABAergic systems",
    "86": "gender/sex differences;",
    "87": "animal studies; brain; dopamine",
    "88": "galactorrhea; case reports",
    "89": "vilazodone; safety efficacy; depression",
    "90": "fibromyalgia; pain; treatment",
    "91": "glaucoma; drug induced;",
    "92": "depression in cancer",
    "93": "plant extracts in mitigating or reversing sexual dysfunction; animal studies",
    "94": "st johns wort",
    "95": "trash",
    "96": "invertebrate models",
    "97": "in vivo; in vitro; serotonin release and uptake in various brain regions",
    "98": "folate levels, neurotransmitters, and antioxidants in depression, ",
    "99": "trash; no abstracts",
    "100": "depression in chronic kidney disease (CKD) and end-stage renal disease (ESRD)",
    "101": "gambling; ccompulsions",
    "103": "ssris against migraine",
    "102": "trash; sertraline; no abstracts",
    "104": "Stress urinary incontinence ",
    "105": "trash; mania; drug induced",
    "106": "ssri use in dogs",
    "107": "microRNAs in depression",
    "108": "animal studies; differential-reinforcement-of-low-rate (DRL) operant schedule in rats",
    "109": "ssri against dysthymia",
    "110": "trichotillomania",
    "111": "trash; no abstracts",
    "112": "prevention of depressive recurrences ",
    "114": "tourette; apathy",
    "113": "interaction between serotonin uptake inhibitors and serotonin autoreceptors; animal studies",
    "115": "generic comparisons",
    "116": "copd; asthma",
    "117": "mutism",
    "118": "multiple sclerosis",
    "119": "paroxetine; g protein",
    "120": "changes in brain-derived neurotrophic factor (BDNF) serum levels in patients with major depressive disorder (MDD) after SSRI treatment",
    "121": "thyroid function",
    "123": "hiv patients",
    "122": "olfactory bulbectomized rat model; animal studies",
    "124": "burning mouth syndrome, treatment; drug induced",
    "125": " Electric Current Therapy ",
    "126": "smoking cessation",
    "127": "huntingtons diseas",
    "129": " syncope, a temporary loss of consciousness caused by a lack of blood flow to the brain",
    "128": "tinnitus; treatment",
    "130": "oudness dependence of auditory evoked potentials (LDAEP)",
    "131": "ecotoxicology;removal of pharmaceutical contaminants from water using various types of activated carbon and other adsorbent materials",
    "132": "hallucinations",
    "133": "exercise",
    "135": "narcolepsy; sleep",
    "134": "zinc levels and antidepressant activity",
    "136": "tryptophan depletion and its effects on mood",
    "137": "neuropeptide, in the mechanisms of depression and antidepressant actions",
    "138": "acupuncture",
    "139": "ongenital myasthenic syndromes",
    "140": "microscopic colitis; drug induced; ibd; bowel disease",
    "141": "supplements",
    "143": "critical psychopharmacology",
    "142": "no abstracts; fluvoxamine; trash; ocd",
    "144": "pharmacology ocd; animal studies",
    "146": "priapism; drug induced",
    "145": "depersonalization disorder; treatment",
    "148": "reversible cerebral vasoconstriction syndrome (RCVS)",
    "147": "psilocybin vs ssri",
    "151": "postpartum depression",
    "149": "cellular distribution of psychotropic drugs; lysosomal trapping ",
    "150": "homeopathic",
    "152": "Gateway to clinical trials; no abstract; trash",
    "153": "talk therapy; no abstracts; trash",
    "154": "olfactory reference syndrome; no abstracts; trash",
    "32;26;26": "family",
}

# %%
import matplotlib.pyplot as plt
import colorcet as cc
import networkx as nx
import pandas as pd
import plotly.graph_objects as go
import sys
from dash import Dash, html
import dash_cytoscape as cytov
import igraph as ig
from IPython.display import Image

sys.path.append("/Users/jlq293/Projects/Study-1-Bibliometrics/src/main_path/")

from MainPathReader import MainPathReader
from MainPathDataAssigner import MainPathDataAssigner
from MainPathPlotterStatic import MainPathPlotterStatic
from MainPathPlotterInteractive import MainPathPlotterInteractive

# %% [markdown]
# # load and prep data

# %%
p = "../data/06-clustered-df/alpha0.3_k10_res0.002.pkl"
df = pd.read_pickle(p)

path_to_main_path = (
    "../data/08-main-paths/3. Key-Route Global Main Path [100-150] of N2 (169).net"
)
mp_reader = MainPathReader(
    path_to_main_path,
    node_attributes=[
        "eid",
    ],
)
Gmp = mp_reader.get_graph()
print(list(Gmp.nodes(data=True))[0])
# Out:
# DiGraph with 169 nodes and 203 edges
# ('1', {'label': 'Magnussen_1982', 'x': '0.9534', 'y': '0.6944', 'size': '0.5000', 'shape': 'ellipse', 'eid': '2-s2.0-0019996341'})

# %%
attr_to_assign = [
    "title",
    "citedby_count",
    "doi",
    "year",
    "cluster_alpha0.3_k10_res0.002",
    "centrality_alpha0.3_k10_res0.002",
]

data_assigner = MainPathDataAssigner(Gmp, df, attr_to_assign)
Gmp = data_assigner.process_mp(attr_to_remove=["x", "y", "size", "shape"])
print(list(Gmp.nodes(data=True))[0])
clusters = nx.get_node_attributes(Gmp, "cluster_alpha0.3_k10_res0.002").values()

print(f"Nr of clusters in Gmp: {len(set(clusters))}")
# Out:
# ('1', {'label': 'Magnussen_1982', 'eid': '2-s2.0-0019996341', 'title': 'Treatment of myoclonic syndromes with paroxetine alone or combined with 5‐HTP', 'citedby_count': '13', 'doi': '10.1111/j.1600-0404.1982.tb04525.x', 'year': '1982', 'centrality_alpha0.3_k10_res0.002': '0.053241691737290625', 'color': '#c5b0d5', 'cluster_label': '39: Psychodermatology', 'cluster_alpha0.3_k10_res0.002': '39'})
# Nr of clusters in Gmp: 26

# %% [markdown]
# # static plot

# %%
# Define a color palette with 24 distinct colors
color_palette = [
    "#1f77b4",
    "#ff7f0e",
    "#2ca02c",
    "#d62728",
    "#9467bd",
    "#8c564b",
    "#e377c2",
    "#7f7f7f",
    "#bcbd22",
    "#17becf",
    "#aec7e8",
    "#ffbb78",
    "#98df8a",
    "#ff9896",
    "#c5b0d5",
    "#c49c94",
    "#f7b6d2",
    "#c7c7c7",
    "#dbdb8d",
    "#9edae5",
    "#c7e9c0",
    "#fddaec",
    "#bcbd22",
    "#e377c2",
    "#1f77b4",
    "#ff7f0e",
]

print(len(color_palette))
# Map clusters to colors
vertex_cluster_colors = {
    cluster: color_palette[i] for i, cluster in enumerate(sorted(set(clusters)))
}

# Assign colors to nodes and remove the original cluster attribute
for node, data in Gmp.nodes(data=True):
    cluster = data.get("cluster_alpha0.3_k10_res0.002", None)
    if cluster is not None:
        color = vertex_cluster_colors[cluster]
        data["color"] = color
        cluster_label = cluster_label_dict[cluster]
        cluster_label = cluster + ": " + cluster_label
        data["cluster_label"] = cluster_label.title()
        del data["cluster_alpha0.3_k10_res0.002"]

print(list(Gmp.nodes(data=True))[0])

# save as graphml
nx.write_graphml(
    Gmp,
    "/Users/jlq293/Projects/Study-1-Bibliometrics/data/08-main-paths/3. Key-Route Global Main Path [100-150] of N2 (169).graphml",
)
# Out:
# 26
# ('1', {'label': 'Magnussen_1982', 'eid': '2-s2.0-0019996341', 'title': 'Treatment of myoclonic syndromes with paroxetine alone or combined with 5‐HTP', 'citedby_count': '13', 'doi': '10.1111/j.1600-0404.1982.tb04525.x', 'year': '1982', 'centrality_alpha0.3_k10_res0.002': '0.053241691737290625', 'color': '#c5b0d5', 'cluster_label': '39: Psychodermatology'})

# %% [markdown]
# ## using matplotlib

# %%
def convert_to_igraph(G):
    return ig.Graph.from_networkx(G)


def attribute_adapter(g):
    g.vs["auth_year"] = [v["label"] for v in g.vs]
    g.vs["label"] = [
        f"{int(v['_nx_name'])-1},{v['cluster_alpha0.3_k10_res0.002']}" for v in g.vs
    ]
    print(g.vs[0])
    return g


def prepare_layout(g):
    layout = g.layout("kamada_kawai")
    return layout


def prep_ig(G):
    g = convert_to_igraph(G)
    g = attribute_adapter(g)
    layout = prepare_layout(g)
    return g, layout

# %%
g, layout = prep_ig(Gmp)


def change_position(layout, node, x_change, y_change):
    x = layout[node][0] + x_change
    y = layout[node][1] + y_change
    layout[node] = (x, y)
    return layout


# layout = change_position(layout, 20, -0.2, -0.1)

# for i in range(0, 70):
# layout = change_position(layout, i, 1.20, 0)

fig, ax = plt.subplots(figsize=(20, 40))

ig.plot(
    g,
    target=ax,
    layout=layout,
    labels=True,
    vertex_size=20,
    font_size=10,
    vertex_color=colors,
    vertex_label=[str(node) for node in g.vs["label"]],
    arrow_size=0.0001,
    edge_curved=False,
    edge_color="#001111",
    margin=100,
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 g, layout = prep_ig(Gmp)
#       4 def change_position(layout, node, x_change, y_change):
#       5     x = layout[node][0] + x_change
#
# Cell In[46], line 21, in prep_ig(G)
#      19 def prep_ig(G):
#      20     g = convert_to_igraph(G)
# ---> 21     g = attribute_adapter(g)
#      22     layout = prepare_layout(g)
#      23     return g, layout
#
# Cell In[46], line 7, in attribute_adapter(g)
#       5 def attribute_adapter(g):
#       6     g.vs["auth_year"] = [v["label"] for v in g.vs]
# ----> 7     g.vs["label"] = [
#       8         f"{int(v['_nx_name'])-1},{v['cluster_alpha0.3_k10_res0.002']}" for v in g.vs
#       9     ]
#      10     print(g.vs[0])
#      11     return g
#
# Cell In[46], line 8, in <listcomp>(.0)
#       5 def attribute_adapter(g):
# ...

# %%
g, layout = prep_ig(Gmp)

# reverse the layout
layout.rotate(180)


def change_position(layout, node, x_change, y_change):
    x = layout[node][0] + x_change
    y = layout[node][1] + y_change
    layout[node] = (x, y)
    return layout


layout = change_position(layout, 20, -0.2, -0.1)
#
# for i in range(0, 70):
#    layout = change_position(layout, i, 1.20, 0)


# Plot with margins
plot = ig.plot(
    g,
    layout=layout,
    bbox=[2000, 3500],
    labels=True,
    vertex_size=50,
    font_size=10,
    vertex_color=colors,
    vertex_label=[str(node) for node in g.vs["label"]],
    arrow_size=0.0001,
    margin=100,
)

# Save or display the plot
filename = "/Users/jlq293/Projects/Study-1-Bibliometrics/output/figures/main-paths/graph_plot.png"
plot.save(filename)
plot
# Out:
# igraph.Vertex(<igraph.Graph object at 0x143f51850>, 0, {'_nx_name': '1', 'label': '0,39', 'eid': '2-s2.0-0019996341', 'title': 'Treatment of myoclonic syndromes with paroxetine alone or combined with 5‐HTP', 'citedby_count': '13', 'doi': '10.1111/j.1600-0404.1982.tb04525.x', 'year': '1982', 'cluster_alpha0.3_k10_res0.002': '39', 'centrality_alpha0.3_k10_res0.002': '0.053241691737290625', 'auth_year': 'Magnussen_1982'})

# %%
import igraph as ig
import matplotlib.pyplot as plt

# Your graph and layout code here
layout = g.layout("kamada_kawai")
# layout.scale(100)
layout.rotate(180)


def change_position(layout, node, x_change, y_change):
    x = layout[node][0] + x_change
    y = layout[node][1] + y_change
    layout[node] = (x, y)
    return layout


layout = change_position(layout, 20, -0.2, -0.1)

# Create the igraph plot
ig_plot = ig.plot(
    g,
    layout=layout,
    bbox=(0, 0, 2000, 3000),  # Adjust as needed
    vertex_size=50,
    vertex_label=[str(node) for node in g.vs["label"]],
    target=None,  # This ensures the plot is not shown, as we'll use Matplotlib to display it
)

# Get the Matplotlib figure and axis objects
fig, ax = plt.subplots()

# Convert the igraph plot to a Matplotlib image and plot it on the Matplotlib axis
ax.imshow(ig_plot, aspect="auto")

# Set any additional configurations for the Matplotlib plot
ax.set_axis_off()  # Hide the axis

# Show the Matplotlib plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Your graph and layout code here
# ----> 5 layout = g.layout("kamada_kawai")
#       6 # layout.scale(100)
#       7 layout.rotate(180)
#
# NameError: name 'g' is not defined

# %% [markdown]
# # interactive plot

# %%
import colorcet as cc
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import plotly.graph_objects as go
import plotly.io as pio


class MainPathPlotterInteractive:
    def __init__(self, G, cluster_col, label_col):
        self.G = G
        self.cluster_col = cluster_col
        self.label_col = label_col

    @staticmethod
    def add_line_breaks(text, char_limit=100):
        words = text.split()
        line = ""
        lines = []
        for word in words:
            if len(line + " " + word) <= char_limit:
                line += " " + word
            else:
                lines.append(line.strip())
                line = word
        if line:
            lines.append(line.strip())
        return "<br>".join(lines)

    def adjust_overlap(self, min_dist=0.1, max_iterations=100):
        """
        Adjusts the positions to reduce overlap.

        :param pos: Dictionary of positions keyed by node.
        :param min_dist: Minimum desired distance between nodes.
        :param max_iterations: Maximum number of iterations to perform adjustments.
        :return: Adjusted positions.
        """
        for _ in range(max_iterations):
            moved = False
            for node1 in self.pos:
                for node2 in self.pos:
                    if node1 != node2:
                        # Calculate the distance between two nodes
                        delta = np.array(self.pos[node1]) - np.array(self.pos[node2])
                        dist = np.sqrt(np.sum(delta**2))
                        # If the nodes are too close, push them apart
                        if dist < min_dist:
                            moved = True
                            displacement = delta / dist * (min_dist - dist) / 2
                            self.pos[node1] += displacement
                            self.pos[node2] -= displacement
            # If no nodes were moved in this iteration, stop the adjustment
            if not moved:
                print(f"Adjustment finished after {_} iterations")
                break
        return self.pos

    def clean_years(self):
        """
        Convert year attribute to integer, if not already
        if multiple years are present, the mean is taken
        """
        # Convert year attribute to integer, if not already
        for node, data in self.G.nodes(data=True):
            if isinstance(data["year"], str):
                mean_year = sum(map(int, data["year"].split(";"))) / len(
                    data["year"].split(";")
                )
                data["year"] = int(mean_year)

        # Sort nodes based on year attribute
        nodes_sorted_by_year = sorted(
            self.G.nodes(data=True), key=lambda x: x[1]["year"], reverse=True
        )

        # Get the range of years
        min_year = min([data["year"] for node, data in nodes_sorted_by_year])
        max_year = max([data["year"] for node, data in nodes_sorted_by_year])

        return min_year, max_year, nodes_sorted_by_year

    def hover_texts(self):
        hover_texts = []
        for node, data in self.G.nodes(data=True):
            wrapped_title = self.add_line_breaks(data["title"])
            hover_title_cluster = (
                f"Cluster: {data[self.cluster_col]}<br>{wrapped_title}"
            )
            hover_title_cluster_cited = f"Cluster: {data[self.cluster_col]}<br>Cited by: {data['citedby_count']}<br>{wrapped_title}"
            hover_texts.append(hover_title_cluster_cited)
        return hover_texts

    def cluster_color_dict(self):
        """
        Creates a dictionary mapping clusters to distinct colors using the colorcet library,
        and returns a list of colors for each node based on its cluster.

        Returns:
            list: A list of color strings in hex format for each node in the graph, based on its cluster.
        """
        clusters = nx.get_node_attributes(self.G, self.cluster_col).values()
        unique_clusters = sorted(set(clusters))

        # Using colorcet to get a colormap with enough distinct colors
        # Adjust the colormap if needed to suit your preferences for color variety and distinctness
        color_list = cc.glasbey_dark[: len(unique_clusters)]

        # Creating a color dictionary mapping each cluster to a color
        color_dict = {
            cluster: color_list[i] for i, cluster in enumerate(unique_clusters)
        }

        # Generating a list of colors for each node based on its cluster
        colors = [color_dict[cluster] for cluster in clusters]
        return colors

    def node_labels(self):
        node_labels = []
        for node, data in self.G.nodes(data=True):
            node_labels.append(data[self.label_col])
        return node_labels

    def edge_positions(self):
        edge_x = []
        edge_y = []
        for edge in self.G.edges():
            x0, y0 = self.pos[edge[0]]
            x1, y1 = self.pos[edge[1]]
            edge_x.append(x0)
            edge_x.append(x1)
            edge_x.append(None)
            edge_y.append(y0)
            edge_y.append(y1)
            edge_y.append(None)
        return edge_x, edge_y

    def get_edge_trace(self):
        edge_x, edge_y = self.edge_positions()
        edge_trace = go.Scatter(
            x=edge_x,
            y=edge_y,
            line=dict(width=0.7, color="#000000"),
            hoverinfo="none",
            mode="lines",
        )
        return edge_trace

    def get_node_trace(self):
        node_x, node_y = zip(*self.pos.values())
        hover_texts = self.hover_texts()
        colors = self.cluster_color_dict()
        node_labels = self.node_labels()
        node_trace = go.Scatter(
            x=node_x,
            y=node_y,
            mode="markers+text",
            hoverinfo="text",
            hovertext=hover_texts,
            text=node_labels,  # Permanent labels for nodes
            textposition="middle center",
            marker=dict(
                showscale=False,
                opacity=0.3,  # Decreased opacity of nodes for the desired transparency
                # colorscale='YlGnBu',
                size=20,
                colorbar=dict(
                    thickness=15,
                    title="Node Connections",
                    xanchor="left",
                    titleside="right",
                ),
                line_width=2,
                color=colors,
            ),
        )
        return node_trace

    def plot_network_on_timeline_interactive(
        self, savingpath=None, return_fig=True, adjust_overlap=True, pos=None
    ):
        # Convert year attribute to integer, if not already
        # min_year, max_year, nodes_sorted_by_year = self.clean_years()

        if not pos:
            self.pos = nx.kamada_kawai_layout(
                self.G,
                weight=None,
                scale=5.0,
                center=None,
                dim=2,
            )  # Use Kamada-Kawai layout for better node positioning
        else:
            self.pos = pos

        if adjust_overlap:
            self.pos = self.adjust_overlap(0.15, 100)

        edge_trace = self.get_edge_trace()

        node_trace = self.get_node_trace()
        width = 1000
        height = 1500
        if len(self.G.nodes) > 190:
            width = 1300
            height = 1500
        # Figure Definition
        fig = go.Figure(
            data=[edge_trace, node_trace],
            layout=go.Layout(
                width=width,  # Example width
                height=height,  # Example height
                showlegend=False,  # Adjust based on your need to show or hide the legend
                hovermode="closest",
                hoverlabel=dict(  # Customizing the hover label's appearance
                    bgcolor="rgba(249, 98, 186, 0.11)",  # Setting the background color to a semi-transparent gray
                    bordercolor="rgba(0, 0, 0, 0.14)",
                    font=dict(color="black"),  # Text color in the hover label
                ),
                margin=dict(b=0, l=0, r=0, t=40),
                xaxis=dict(
                    showline=False,  # Hides the axis line
                    showgrid=False,
                    zeroline=False,
                    showticklabels=False,  # Hide tick labels
                    visible=False,  # Makes the whole axis (including the space for it) invisible
                ),
                yaxis=dict(
                    showline=False,  # Hides the axis line
                    showgrid=False,
                    zeroline=False,
                    showticklabels=False,  # Hide tick labels
                    visible=False,  # Makes the whole axis (including the space for it) invisible
                ),
                dragmode="zoom",
            ),
        )

        plt.tight_layout()
        if savingpath:
            if savingpath.endswith(".html"):  # Use 'savingpath' consistently
                fig.write_html(savingpath)
            elif savingpath.endswith(".png"):
                fig.write_image(savingpath, dpi=300)
        fig.show()
        if return_fig:
            return pio.to_html(fig, full_html=False, include_plotlyjs="cdn")

# %%
list(Gmp.nodes(data=True))[0]
# Out:
# ('1',
#  {'label': 'Magnussen_1982',
#   'eid': '2-s2.0-0019996341',
#   'title': 'Treatment of myoclonic syndromes with paroxetine alone or combined with 5‐HTP',
#   'citedby_count': '13',
#   'doi': '10.1111/j.1600-0404.1982.tb04525.x',
#   'year': '1982',
#   'centrality_alpha0.3_k10_res0.002': '0.053241691737290625',
#   'color': '#c5b0d5',
#   'cluster_label': '39: Psychodermatology'})

# %%
# plot interactive
plotter = MainPathPlotterInteractive(Gmp, "cluster_alpha0.3_k10_res0.002", "label")
plotter.plot_network_on_timeline_interactive(
    savingpath="/Users/jlq293/Projects/PharmaceuticalsAndPublications/testfigs/testfig.html",
    return_fig=False,
    adjust_overlap=True,
    pos=None,
)
